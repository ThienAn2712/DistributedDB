# %% [markdown]
# # Thao tác Dữ liệu (CRUD) - Máy 2 (CN002)

# %%
import pymongo
import datetime

IP_MAY_1 = '100.80.212.106'
IP_MAY_2 = '100.118.59.95'

db_name = 'fahasa_btl2'

print("Đang kết nối tới 2 cluster...")
client_1 = pymongo.MongoClient(f'mongodb://{IP_MAY_1}:27017/', serverSelectionTimeoutMS=5000)
client_2 = pymongo.MongoClient(f'mongodb://{IP_MAY_2}:27017/', serverSelectionTimeoutMS=5000)

# Định nghĩa sessions cho Máy 2: Local là client_2, Remote là client_1
clients = [client_2, client_1]

print("========== Kiểm tra kết nối 2 máy thuộc 2 cluster ==========")
print("Đã thiết lập kết nối thành công từ Máy 2 (CN2)!")
# Out:
# Đang kết nối tới 2 cluster...
# ========== Kiểm tra kết nối 2 máy thuộc 2 cluster ==========
# Đã thiết lập kết nối thành công từ Máy 2 (CN2)!

# %%
def crud_ops(operation, clients, db_name, collection_name, data=None, condition=None):
    # Xử lý Insert
    if operation == 'insert':
        try:
            if 'MaCN' in data:
                # Logic trong suốt cho dữ liệu Phân mảnh (Fragmentation)
                target_client = clients[0] # Mặc định
                if data.get('MaCN') == 'CN001':
                    target_client = client_1
                elif data.get('MaCN') == 'CN002':
                    target_client = client_2
                
                target_client[db_name][collection_name].insert_one(data)
            else:
                # Logic trong suốt cho dữ liệu Nhân bản (Replication)
                for client in clients:
                    client[db_name][collection_name].insert_one(data)
            return True
        except Exception as e:
            print(f"Insert failed: {e}")
            return False

    # Xử lý Update / Delete
    success = False
    for i, client in enumerate(clients):
        try:
            count = client[db_name][collection_name].count_documents(condition)
            if count > 0:
                if operation == 'update':
                    client[db_name][collection_name].update_many(condition, data)
                elif operation == 'delete':
                    client[db_name][collection_name].delete_many(condition)
                
                success = True
            else:
                pass 
        except Exception as e:
            print(f"Error executing: {e}")
            continue
            
    if not success:
        print("Không tìm thấy dữ liệu ở bất kỳ chi nhánh nào trong hệ thống.")
        return False
        
    return True

# %% [markdown]
# ## 1. Thêm dữ liệu
# ### Trường hợp demo thêm dữ liệu vào Máy 1 (Chi nhánh 1)
# Máy 2 tiến hành thao tác thêm dữ liệu vào cơ sở dữ liệu ở CN001, sau đó kiểm tra tính đúng đắn (chỉ thêm vào CN001, không thêm nhầm vào CN002).

# %%
nv9001 = {
    '_id': 'NV9001', 'MaCN': 'CN001', 'HoTen': 'Trần Lê Duy Tân', 
    'GioiTinh': 'Nam', 'NgaySinh': datetime.datetime(2005, 6, 16),
    'SoDienThoai': '0999999991', 'NgayVaoLam': datetime.datetime.now()
}

print("--- Máy 2 thực hiện Insert dữ liệu nhân viên NV9001---")
crud_ops('insert', clients, db_name, 'nhanvien', data=nv9001)

print("\n--- Máy 2 kiểm tra tính đúng đắn ở cả 2 chi nhánh ---")
nv_cn1 = client_1[db_name]['nhanvien'].find_one({'_id': 'NV9001'})
nv_cn2 = client_2[db_name]['nhanvien'].find_one({'_id': 'NV9001'})

print("\nDữ liệu ở Máy 1 (CN1):", nv_cn1 if nv_cn1 else "Không tồn tại")
print("\nDữ liệu ở Máy 2 (CN2):", nv_cn2 if nv_cn2 else "Không tồn tại")
# Out:
# --- Máy 2 thực hiện Insert dữ liệu nhân viên NV9001---
#
# --- Máy 2 kiểm tra tính đúng đắn ở cả 2 chi nhánh ---
#
# Dữ liệu ở Máy 1 (CN1): {'_id': 'NV9001', 'MaCN': 'CN001', 'HoTen': 'Trần Lê Duy Tân', 'GioiTinh': 'Nam', 'NgaySinh': datetime.datetime(2005, 6, 16, 0, 0), 'SoDienThoai': '0999999991', 'NgayVaoLam': datetime.datetime(2026, 5, 29, 1, 23, 30, 374000)}
#
# Dữ liệu ở Máy 2 (CN2): Không tồn tại

# %% [markdown]
# ### Trường hợp demo thêm dữ liệu vào Máy 2 (Chi nhánh 2)
# Máy 2 kiểm tra xem **Máy 1** đã thực hiện thêm nhân viên `NV9002` vào CN002 thành công hay chưa.

# %%
print("--- Máy 2 kiểm tra lại kết quả Insert của Máy 1 ---")
nv_cn2 = client_2[db_name]['nhanvien'].find_one({'_id': 'NV9002'})
print("Dữ liệu ở Máy 2 (CN2):", nv_cn2 if nv_cn2 else "Không tồn tại")
# Out:
# --- Máy 2 kiểm tra lại kết quả Insert của Máy 1 ---
# Dữ liệu ở Máy 2 (CN2): {'_id': 'NV9002', 'MaCN': 'CN002', 'HoTen': 'Lưu Quang Huy', 'GioiTinh': 'Nữ', 'NgaySinh': datetime.datetime(2005, 1, 4, 0, 0), 'SoDienThoai': '0999999992', 'NgayVaoLam': datetime.datetime(2026, 5, 29, 1, 9, 49, 831000)}

# %% [markdown]
# ## 2. Cập nhật dữ liệu
# **Tính trong suốt phân tán thể hiện trong trường hợp này như sau:** Khi Máy 2 thực hiện thao tác, logic xử lý sẽ tự động kiểm tra xem nhân viên đó được tạo ở chi nhánh nào. Từ đó hệ thống xác định được dữ liệu thuộc chi nhánh nào và tiến hành thao tác tương ứng trên chi nhánh đó (mà không cần người dùng/ứng dụng phải tự chỉ định cụ thể Máy 1 hay Máy 2).
#
# ### Trường hợp demo cập nhật dữ liệu ở Máy 1 (Chi nhánh 1)
# **Máy 2** tiến hành cập nhật dữ liệu ở CN001, sau đó kiểm tra tính đúng đắn ở cả 2 chi nhánh.

# %%
print("--- Máy 2 thực hiện Update dữ liệu nhân viên NV9001 ---")
crud_ops('update', clients, db_name, 'nhanvien', condition={'_id': 'NV9001'}, data={'$set': {'SoDienThoai': '0888888881'}})

print("\n--- Máy 2 kiểm tra tính đúng đắn ở cả 2 chi nhánh ---")
nv_cn1_upd = client_1[db_name]['nhanvien'].find_one({'_id': 'NV9001'})
nv_cn2_upd = client_2[db_name]['nhanvien'].find_one({'_id': 'NV9001'})

print("\nDữ liệu ở Máy 1 (CN1):", nv_cn1_upd if nv_cn1_upd else "Không tồn tại")
print("\nDữ liệu ở Máy 2 (CN2):", nv_cn2_upd if nv_cn2_upd else "Không tồn tại")
# Out:
# --- Máy 2 thực hiện Update dữ liệu nhân viên NV9001 ---
#
# --- Máy 2 kiểm tra tính đúng đắn ở cả 2 chi nhánh ---
#
# Dữ liệu ở Máy 1 (CN1): {'_id': 'NV9001', 'MaCN': 'CN001', 'HoTen': 'Trần Lê Duy Tân', 'GioiTinh': 'Nam', 'NgaySinh': datetime.datetime(2005, 6, 16, 0, 0), 'SoDienThoai': '0888888881', 'NgayVaoLam': datetime.datetime(2026, 5, 29, 1, 23, 30, 374000)}
#
# Dữ liệu ở Máy 2 (CN2): Không tồn tại

# %% [markdown]
# ### Trường hợp demo cập nhật dữ liệu ở Máy 2 (Chi nhánh 2)
# Máy 2 kiểm tra xem **Máy 1** đã cập nhật số điện thoại của nhân viên `NV9002` thành công hay chưa.

# %%
print("--- Máy 2 kiểm tra kết quả Update của Máy 1 ---")
nv_cn2_upd2 = client_2[db_name]['nhanvien'].find_one({'_id': 'NV9002'})
print("Dữ liệu ở Máy 2 (CN2):", nv_cn2_upd2 if nv_cn2_upd2 else "Không tồn tại")
# Out:
# --- Máy 2 kiểm tra kết quả Update của Máy 1 ---
# Dữ liệu ở Máy 2 (CN2): {'_id': 'NV9002', 'MaCN': 'CN002', 'HoTen': 'Lưu Quang Huy', 'GioiTinh': 'Nữ', 'NgaySinh': datetime.datetime(2005, 1, 4, 0, 0), 'SoDienThoai': '0888888882', 'NgayVaoLam': datetime.datetime(2026, 5, 29, 1, 9, 49, 831000)}

# %% [markdown]
# ## 3. Xóa dữ liệu
# **Tính trong suốt phân tán thể hiện trong trường hợp này như sau:** Khi Máy 2 thực hiện thao tác, logic xử lý sẽ tự động kiểm tra xem nhân viên đó được tạo ở chi nhánh nào. Từ đó hệ thống xác định được dữ liệu thuộc chi nhánh nào và tiến hành thao tác tương ứng trên chi nhánh đó (mà không cần người dùng/ứng dụng phải tự chỉ định cụ thể Máy 1 hay Máy 2).
#
# ### Trường hợp demo xoá dữ liệu ở Máy 1 (Chi nhánh 1)
# **Máy 2** tiến hành xoá dữ liệu ở CN001, sau đó kiểm tra tính đúng đắn ở cả 2 chi nhánh.

# %%
print("--- Máy 2 thực hiện Delete dữ liệu nhân viên NV9001 ---")
crud_ops('delete', clients, db_name, 'nhanvien', condition={'_id': 'NV9001'})

print("\n--- Máy 2 kiểm tra tính đúng đắn ở cả 2 chi nhánh ---")
nv_cn1_del = client_1[db_name]['nhanvien'].find_one({'_id': 'NV9001'})
nv_cn2_del = client_2[db_name]['nhanvien'].find_one({'_id': 'NV9001'})

print("\nDữ liệu ở Máy 1 (CN1):", nv_cn1_del if nv_cn1_del else "Không tồn tại")
print("\nDữ liệu ở Máy 2 (CN2):", nv_cn2_del if nv_cn2_del else "Không tồn tại")
# Out:
# --- Máy 2 thực hiện Delete dữ liệu nhân viên NV9001 ---
#
# --- Máy 2 kiểm tra tính đúng đắn ở cả 2 chi nhánh ---
#
# Dữ liệu ở Máy 1 (CN1): Không tồn tại
#
# Dữ liệu ở Máy 2 (CN2): Không tồn tại

# %% [markdown]
# ### Trường hợp demo xoá dữ liệu ở Máy 2 (Chi nhánh 2)
# Máy 2 kiểm tra xem **Máy 1** đã xoá nhân viên `NV9002` thành công hay chưa.

# %%
print("--- Máy 2 kiểm tra kết quả Delete của Máy 1 ---")
nv_cn2_del2 = client_2[db_name]['nhanvien'].find_one({'_id': 'NV9002'})
print("Dữ liệu ở Máy 2 (CN2):", nv_cn2_del2 if nv_cn2_del2 else "Không tồn tại")
# Out:
# --- Máy 2 kiểm tra kết quả Delete của Máy 1 ---
# Dữ liệu ở Máy 2 (CN2): Không tồn tại
